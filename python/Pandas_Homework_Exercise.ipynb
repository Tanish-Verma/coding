# %% [markdown]
# ## Homework exercise

# %% [markdown]
# ### Read the titanic data from the below url as a pandas dataframe
#
# url = "https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv"

# %% [markdown]
# #### <font color='maroon'>Data Variable Description</font>
#
# - Pclass: Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# - survival: Survival (0 = No; 1 = Yes)
# - name: Name
# - sex: Sex
# - age: Age
# - sibsp: Number of Siblings/Spouses Aboard
# - parch: Number of Parents/Children Aboard
# - ticket: Ticket Number
# - fare: Passenger Fare (British pound)
# - cabin: Cabin
# - embarked: Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
# - boat: Lifeboat
# - body: Body Identification Number
# - home.dest: Home/Destination

# %% [markdown]
# #### <font color='blue'> Answer the following questions </font>
#
# 1. How many observations are in the Dataframe "titanic"?
# 2. What is the age of the youngest person in the data?
# 3. How to convert the Age column of the Dataframe into a numpy array?
# 4. Check for "NaN" in Age column. Are there any?
# 5. What is the name of the oldest person in the data?
# 6. Plot a histogram of column "Fare"
# 7. Create a new column called "status", that bins passengers based on their Fare price. Low-income: Fare <= 10; Middle-income: 10 < Fare <= 100; High-income: Fare > 100
# 8. From the data filter out how many passengers survived?
# 9. What is the mean age of the survivors?
# 10. How many passengers died in the titanic?
# 11. Find out the male survivors above the age 60.
# 12. Within the each status group find the count of Males and Females?
# 13. Slice the dataframe to show all the rows but only the columns "Passenger id "  and "Age".
# 14. Sort the data of surviors with decreasing age.
# 15. What different family sizes (i.e. the “SibSp” column) exist in the passenger list?
# 16. What are the names of the people in the largest family group (i.e. the “SibSp” column)?
# 17. Create a scatter plot presenting the relationship between Fare and Age.
