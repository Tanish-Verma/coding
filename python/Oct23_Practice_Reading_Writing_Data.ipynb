# %% [markdown]
# ### How to read and write down data file in python?

# %%
import numpy as np
import pandas as pd

# %%
# f = open(filename, mode)

# %% [markdown]
# ### Example1:

# %%
#Write
f = open('test.txt', 'w')
for i in range(5):
    f.write(f"This is line {i}\n")
    
f.close()

# %%
#Append
f = open('test.txt', 'a')
f.write(f"This is another line\n")
f.close()

# %%
#Read
f = open('test.txt', 'r')
content = f.read()
f.close()
print(content)
# Out:
# This is line 0
# This is line 1
# This is line 2
# This is line 3
# This is line 4
# This is another line

# %%
type(content)
# Out:
# str

# %% [markdown]
# ### Types of modes:
#
# "x" is similar to "w". But for "x", if the file exists, raise FileExistsError. For "w", it will simply create a new file / truncate the existed file.
#
# ![Read_Write.png](attachment:Read_Write.png)

# %% [markdown]
# ![ExWNT-white-bg.png](attachment:ExWNT-white-bg.png)

# %%
# Read line by line

f = open('./test.txt', 'r')
contents = f.readlines()
f.close()
print(contents)
# Out:
# ['This is line 0\n', 'This is line 1\n', 'This is line 2\n', 'This is line 3\n', 'This is line 4\n', 'This is another line\n']

# %%
type(contents)
# Out:
# list

# %% [markdown]
# **Exercise:** Write (or save) an numpy array as a txt file and read it

# %%
arr=np.random.random((10,2))
np.savetxt('my_arr.txt',arr,fmt='%f')

# %% [markdown]
# ####  DataFrame is structured in a tidy data format.
#
# Tidy data format means we have multiple columns of data that collected in a Pandas Dataframe.
#
# ![tidy_data.png](attachment:tidy_data.png)

# %% [markdown]
# - Pandas supported [file formats](https://pandas.pydata.org/docs/user_guide/io.html) for tidy data.
#
# - Numpy supported [file formats](https://numpy.org/doc/stable/reference/routines.io.html).
#
# Some examples of file formats are given below:
#
# ![file_formats.png](attachment:file_formats.png)

# %% [markdown]
# ### Example: CSV file
#
# comma-separated values (CSV) file format, a delimited text file that uses a comma to separate values.

# %%
data = np.random.random((10,5))
data
# Out:
# array([[0.35682809, 0.54331403, 0.67043743, 0.64129247, 0.82629975],
#        [0.71685894, 0.54828379, 0.26652327, 0.0153727 , 0.4371994 ],
#        [0.8869959 , 0.43651915, 0.33853878, 0.27597593, 0.56299246],
#        [0.62753968, 0.64814247, 0.95452976, 0.68046599, 0.26589666],
#        [0.54483828, 0.99770686, 0.75070203, 0.39833669, 0.00319153],
#        [0.13066419, 0.50329051, 0.27018893, 0.90864979, 0.54199596],
#        [0.92360741, 0.72360481, 0.88906526, 0.90101829, 0.15554912],
#        [0.34410457, 0.21195981, 0.02482624, 0.29397703, 0.20312813],
#        [0.00422923, 0.53898685, 0.925625  , 0.60129847, 0.94183045],
#        [0.86818548, 0.01355462, 0.13224504, 0.71108263, 0.69732121]])

# %%
#Write
np.savetxt('test.csv', data, fmt = '%.2f', delimiter=',', header = 'c1, c2, c3, c4, c5')

# %%
#Read
my_csv = np.loadtxt('./test.csv', delimiter=',')
my_csv
# my_csv[:5, :]
# Out:
# array([[0.36, 0.54, 0.67, 0.64, 0.83],
#        [0.72, 0.55, 0.27, 0.02, 0.44],
#        [0.89, 0.44, 0.34, 0.28, 0.56],
#        [0.63, 0.65, 0.95, 0.68, 0.27],
#        [0.54, 1.  , 0.75, 0.4 , 0.  ],
#        [0.13, 0.5 , 0.27, 0.91, 0.54],
#        [0.92, 0.72, 0.89, 0.9 , 0.16],
#        [0.34, 0.21, 0.02, 0.29, 0.2 ],
#        [0.  , 0.54, 0.93, 0.6 , 0.94],
#        [0.87, 0.01, 0.13, 0.71, 0.7 ]])

# %% [markdown]
# **Exercise**: Pandas has a very nice interface for writing and reading CSV files

# %% [markdown]
# Caution! When working with floating point numbers you should be careful to save the data with enough decimal places so that you won't lose precision.

# %% [markdown]
# ### Example: Pickle file

# %%
import pickle

# %% [markdown]
# #### Pickle format
#
# Type: __Binary__
#
# - For cases, we want to store dictionaries, tuples, lists, or any other data type to the disk and use them later.
# - Pickle can serialize objects so that they can be saved into a file and loaded again later.
# - __Serialization__ is the process of converting the object into a format that can be stored or transmitted.
# - Pickle is a powerful serializaion format in python.
# - However, it is not a format you will want to use for long term storage or data sharing.

# %%
#Write a pickle file

dict_a = {'A':0, 'B':1, 'C':2}
arr=np.random.random((10,10))
pickle.dump(arr, open('ARRAY.txt','wb'))
pickle.dump(dict_a, open('test.pkl', 'wb'))

# %% [markdown]
# Note! 'b' stands for binary mode

# %%
#Read a pickle file

my_dict = pickle.load(open('./test.pkl', 'rb'))
my_dict
my_arr=pickle.load(open('ARRAY.txt','rb'))
print(my_arr)
# Out:
# [[0.66435638 0.4846315  0.09476238 0.17056912 0.235566   0.85621503
#   0.46593696 0.04372291 0.72290419 0.84993174]
#  [0.50486361 0.03830017 0.07210136 0.6078701  0.67489001 0.0225424
#   0.48358295 0.70564131 0.54722495 0.10661411]
#  [0.8401017  0.51082812 0.61176727 0.49042967 0.59328609 0.23492226
#   0.3925792  0.24790757 0.94138001 0.9817755 ]
#  [0.51785308 0.29605994 0.40278445 0.62084796 0.99136603 0.05152366
#   0.76113994 0.22335935 0.88368837 0.25235437]
#  [0.75183946 0.89792326 0.52009709 0.204918   0.69534294 0.23760522
#   0.22723071 0.92768044 0.48507934 0.58185273]
#  [0.01248971 0.68052234 0.55652484 0.83047766 0.567437   0.27065247
#   0.94401379 0.64519637 0.10797973 0.40102284]
#  [0.73188569 0.58446505 0.7175924  0.37053224 0.50447548 0.82978134
#   0.36683233 0.4934049  0.64205542 0.69669808]
#  [0.5863574  0.45309564 0.54172946 0.55457692 0.86357875 0.83076326
#   0.0570577  0.87504556 0.51117437 0.43120271]
#  [0.70071614 0.0247538  0.11874025 0.6350153  0.02864703 0.3566835
#   0.36007439 0.70468227 0.17565362 0.5059865 ]
#  [0.54128249 0.68902557 0.06100289 0.23243974 0.4112392  0.86736631
#   0.38654829 0.25810643 0.92136618 0.37566106]]

# %% [markdown]
# **Exercise**: Save a numpy array to a pickle file

# %% [markdown]
# **Exercise**: Save a dataframe to a pickle file

# %%
df=pd.DataFrame(np.random.random((10,10)))
pickle.dump(df,open('my_df.txt','wb'))
my_df=pickle.load(open('my_df.txt','rb'))
print(my_df)
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.503637  0.916895  0.066646  0.791802  0.782570  0.764536  0.188281
# 1  0.717812  0.745001  0.931508  0.891416  0.685940  0.653423  0.016831
# 2  0.702441  0.260461  0.577636  0.563764  0.394513  0.099772  0.571297
# 3  0.168271  0.356637  0.326493  0.961651  0.304149  0.319708  0.666308
# 4  0.974172  0.180022  0.968312  0.699046  0.637694  0.348075  0.002545
# 5  0.781346  0.827493  0.498150  0.364069  0.631906  0.065151  0.297704
# 6  0.450487  0.734607  0.149908  0.496651  0.651453  0.202091  0.679952
# 7  0.239313  0.945776  0.076025  0.315421  0.086248  0.338154  0.920710
# 8  0.882744  0.132978  0.302222  0.374093  0.456379  0.497438  0.212108
# 9  0.366063  0.712539  0.645329  0.949181  0.565211  0.876247  0.443227
#
#           7         8         9
# 0  0.994097  0.361155  0.491750
# 1  0.706467  0.377255  0.112333
# 2  0.827621  0.279448  0.632390
# 3  0.077952  0.762492  0.071196
# 4  0.897799  0.560104  0.368790
# 5  0.499737  0.502381  0.403086
# 6  0.547149  0.275991  0.631159
# 7  0.485034  0.588315  0.925214
# 8  0.829305  0.184042  0.872110
# 9  0.168637  0.361362  0.115056

# %% [markdown]
# **Some other formats for storing tidy data**
#
# **Feather**
#
# - A (binary) file format for storing dataframes (tidy datat) quickly.
# - Compatible with Python, R, and Julia.
# - require package pyarrow (pip install pyarrow)
#
# **Parquet**
#
# - A (binary) file format for storing large tidy data.
# - Parquet is used by many different languages (C, Java, Python, MATLAB, Julia, etc.).
# - require package pyarrow (pip install pyarrow)

# %% [markdown]
# ### Example: JSON file

# %% [markdown]
# __JSON (JavaScript Object Notation)__
#
# __Type: Text format__
#
# - Extension “.json”.
# - Human-readable.
# - Common when dealing with web applications.
# - Unlike pickle, which is Python dependent, JSON is a language-independent data format, which makes it attractive to use.

# %%
import json

# %%
#Write a dictionary to a JSON file 

school = {
  "school": "UC Berkeley",
  "address": {
    "city": "Berkeley", 
    "state": "California",
    "postal": "94720"
  }, 
    
  "list":[
      "student 1",
      "student 2",
      "student 3"
      ],
    
  "array":[1, 2, 3]
}

school
# Out:
# {'school': 'UC Berkeley',
#  'address': {'city': 'Berkeley', 'state': 'California', 'postal': '94720'},
#  'list': ['student 1', 'student 2', 'student 3'],
#  'array': [1, 2, 3]}

# %%
json.dump(school, open('school.json', 'w'))

# %%
#Read

my_school = json.load(open('./school.json', 'r'))
my_school
# Out:
# {'school': 'UC Berkeley',
#  'address': {'city': 'Berkeley', 'state': 'California', 'postal': '94720'},
#  'list': ['student 1', 'student 2', 'student 3'],
#  'array': [1, 2, 3]}

# %% [markdown]
# **Exercise**: Save a dataframe to a JSON file

# %% [markdown]
# ### Example: HDF5 file

# %% [markdown]
# __HDF5 (Hierarchical Data Format version 5)__
#
# __Type: Binary format__
#
# - Extension “.hdf5”.
# - Packages needed: numpy, pandas, PyTables, h5py
# - The h5py package is a Python library that provides an interface to the HDF5 format.
# - **Best use cases**: Working with big datasets in array data format and no limit on the file size.
# - Carries out a bunch of low level optimizations under the hood to make the queries faster and storage requirements smaller.
# - An HDF5 file saves two types of objects:
#    - _datasets_, which are array-like collections of data (like NumPy arrays),
#    - _groups_, which are folder-like containers that hold datasets and other groups.
# - __hierarchical__ in HDF5 refers to the fact that the data could be saved like a file system, with folder-like structures, such as folder, subfolder (in HDF5, it is called group, subgroup).

# %%
import h5py

# %%
data = np.random.random((10,5))
data
# Out:
# array([[0.78597813, 0.08722767, 0.63646057, 0.87113085, 0.78730829],
#        [0.29894507, 0.11366649, 0.94600806, 0.33778226, 0.02058429],
#        [0.17726002, 0.23266204, 0.41052353, 0.59008503, 0.9708968 ],
#        [0.52167772, 0.33147047, 0.0442382 , 0.21834877, 0.11342057],
#        [0.24805063, 0.96464717, 0.4570567 , 0.44032745, 0.40107686],
#        [0.93134109, 0.94116567, 0.47402146, 0.90412595, 0.35241304],
#        [0.78512145, 0.46015961, 0.99324263, 0.78381942, 0.08233419],
#        [0.60624065, 0.85776359, 0.49944868, 0.93590176, 0.43432312],
#        [0.75867325, 0.09751132, 0.54605057, 0.53842569, 0.02032436],
#        [0.20406831, 0.48876237, 0.62345707, 0.66315414, 0.4083998 ]])

# %%
## Write

with h5py.File('data_array.hdf5', 'w') as hf:
    hf.create_dataset('hdf5_data',data=data)

# %%
## Read

with h5py.File('data_array.hdf5', 'r') as hf:
    hdf5_read = hf['hdf5_data'][:]

hdf5_read
# Out:
# array([[0.78597813, 0.08722767, 0.63646057, 0.87113085, 0.78730829],
#        [0.29894507, 0.11366649, 0.94600806, 0.33778226, 0.02058429],
#        [0.17726002, 0.23266204, 0.41052353, 0.59008503, 0.9708968 ],
#        [0.52167772, 0.33147047, 0.0442382 , 0.21834877, 0.11342057],
#        [0.24805063, 0.96464717, 0.4570567 , 0.44032745, 0.40107686],
#        [0.93134109, 0.94116567, 0.47402146, 0.90412595, 0.35241304],
#        [0.78512145, 0.46015961, 0.99324263, 0.78381942, 0.08233419],
#        [0.60624065, 0.85776359, 0.49944868, 0.93590176, 0.43432312],
#        [0.75867325, 0.09751132, 0.54605057, 0.53842569, 0.02032436],
#        [0.20406831, 0.48876237, 0.62345707, 0.66315414, 0.4083998 ]])

# %% [markdown]
# **Exercise**: Save a dataframe to a pickle file

# %%
data1=np.random.randint((10,10))
datafram=pd.DataFrame(data1)
datafram.to_hdf('datafram.hdf5',key='DataFrame',mode='w')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\Tanish\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File c:\Users\Tanish\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'tables'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[65], line 3
#       1 data1=np.random.randint((10,10))
#       2 datafram=pd.DataFrame(data1)
# ----> 3 datafram.to_hdf('datafram.hdf5',key='DataFrame',mode='w')
#
# File c:\Users\Tanish\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\Tanish\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:2855, in NDFrame.to_hdf(self, path_or_buf, key, mode, complevel, complib, append, format, index, min_itemsize, nan_rep, dropna, data_columns, errors, encoding)
#    2851 from pandas.io import pytables
#    2853 # Argument 3 to "to_hdf" has incompatible type "NDFrame"; expected
#    2854 # "Union[DataFrame, Series]" [arg-type]
# -> 2855 pytables.to_hdf(
#    2856     path_or_buf,
#    2857     key,
#    2858     self,  # type: ignore[arg-type]
#    2859     mode=mode,
#    2860     complevel=complevel,
#    2861     complib=complib,
#    2862     append=append,
#    2863     format=format,
#    2864     index=index,
#    2865     min_itemsize=min_itemsize,
#    2866     nan_rep=nan_rep,
#    2867     dropna=dropna,
#    2868     data_columns=data_columns,
#    2869     errors=errors,
#    2870     encoding=encoding,
#    2871 )
#
# File c:\Users\Tanish\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\pytables.py:308, in to_hdf(path_or_buf, key, value, mode, complevel, complib, append, format, index, min_itemsize, nan_rep, dropna, data_columns, errors, encoding)
#     306 path_or_buf = stringify_path(path_or_buf)
#     307 if isinstance(path_or_buf, str):
# --> 308     with HDFStore(
#     309         path_or_buf, mode=mode, complevel=complevel, complib=complib
#     310     ) as store:
#     311         f(store)
#     312 else:
#
# File c:\Users\Tanish\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\pytables.py:566, in HDFStore.__init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     563 if "format" in kwargs:
#     564     raise ValueError("format is not a defined argument for HDFStore")
# --> 566 tables = import_optional_dependency("tables")
#     568 if complib is not None and complib not in tables.filters.all_complibs:
#     569     raise ValueError(
#     570         f"complib only supports {tables.filters.all_complibs} compression."
#     571     )
#
# File c:\Users\Tanish\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'pytables'.  Use pip or conda to install pytables.
